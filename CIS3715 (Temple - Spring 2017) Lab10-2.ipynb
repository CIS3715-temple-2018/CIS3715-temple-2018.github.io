# %% [markdown]
# ## Lab 10, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 20 epochs are required before the generated text
# starts sounding coherent.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 200285
# Vectorization...

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ### Training (reduce the number of epochs, it takes a lot of time!!)
# -  Each epoch takes 5-10 minutes or so on a CPU (an epoch took 7.5 minutes for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (2-3 hours)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
model.save('shakespear100.h5')
# Out:
# Epoch 1/10
# 200285/200285 [==============================] - 42s 208us/step - loss: 1.9961
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "e control of women, in the marriage cust"
# e control of women, in the marriage cust in the proper of the proper and strect of the sumet and the such and the proper of the proper and the suphisting of the proper of the such the the and and the such the super the consification of the proper of the strection of the proper of the super of the man interpress of the prople of the such intellest that is a contine of the man interpoure of the super and the superstand in the super that i
# ----- diversity: 0.5
# ----- Generating with seed: "e control of women, in the marriage cust"
# e control of women, in the marriage cust propection of fuelly to the spirit of hempentuly that in the proposity of the has of the superstanting that the something with rither and let propliance case of littous and still is with the into the man interman to perhaps inter the conternations of the scirction, its end, the present in the respect of the that in the condicion of the intirnce of the be
# noule of the experse of incondivet.
#
#
#
#
#
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "e control of women, in the marriage cust"
# e control of women, in the marriage cust alliwitic
# samaler belief, want we of the whe ease disparting indesont; that of conrinced, than be, dist
# man foll, crreates, staking forong, litune, beto confinulance. we his phtes imparifans  meence of which be attibut is be
# introumes betach plapopre sunkinus
# deslys it of the clust one
# interpadi greling we ut say bet exthingopichim of persime mankinesly sacke," he has bean antight conted liketiou
# ----- diversity: 1.2
# ----- Generating with seed: "e control of women, in the marriage cust"
# e control of women, in the marriage custince but ay we campy,iman cettarms wto dight as i foursorityvinades -fo mons to that still miraulisns; foum imme nate be agn derigind cods,
# any 4ndical indicimulic bo gond; yhery be
# a jusnd desare nene" for grranx would of the lave to
# like
# a find. and he
# sainced -suppopeaasying "intiimed, what can. ty, metings, the uit . "full that still, nor-germon advirmatip work an oppasion any
# be the pature.
# -
# Epoch 2/10
# 200285/200285 [==============================] - 41s 206us/step - loss: 1.6527
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " community is only
# kept in view, and the"
#  community is only
# kept in view, and the believe and stand and the stand that in the some the the still the strength, and the secience of the subject and constined to the constined the strength, and the still to the strength of the stands and the the strength is a subject of the stands of the strength is the standing of the spirits and the subject and still and and the strength of the strength of the procistion of the stand and and the
# ----- diversity: 0.5
# ----- Generating with seed: " community is only
# kept in view, and the"
#  community is only
# kept in view, and the desired that that the explaty to the believe, and the compresental it is not not in the intoption of moral in the with for the most scurined to every in the still be an among the strengthed by his a concemental the science, that so the they have betterful, of which is it in the spired on the problem it is power--from the the explacial on the some have only herear for a strong and life, but a proc
# ----- diversity: 1.0
# ----- Generating with seed: " community is only
# kept in view, and the"
#  community is only
# kept in view, and the examefines.
#
# -73 cin in merst appeat: hefated, and their forcevent), with li stoly. one haddined in banges heant, in
# which,
# that and
# for delight and iumingaca--abligational ilse of a
# cluneabla
# in "consist himself.' to fut pets and the inother world; slaw beceffice it reversted
# to siluton.,
# but all that rease for now the philosophojy; that
# hausatlizis in the feels cimply) strangthanned, my
# powinge
# ----- diversity: 1.2
# ----- Generating with seed: " community is only
# kept in view, and the"
#  community is only
# kept in view, and the whenshaph a
# nist. it
# desinally
# benofts and stelled the beams: to ablestening mort "tould to hay becomer, in
# excustroffinite us--im readinuslomed nifowade
# ippariemfule cintratiation, has the allwaonom in flighone an from afthm the others,
# the still, with lest, reavomendes ritservicake" undermosi. (prelegen is ure for wet impeasce, only ecerciss of mibadippeht came payrinice fon, the circum wfolly,
# Epoch 3/10
# 200285/200285 [==============================] - 42s 209us/step - loss: 1.5572
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ying out of which all refined pride, all"
# ying out of which all refined pride, all the consequently and something and the sense of the stands in the seems and seems to the seems and at the self-sense of the present and an and the more the seems to a stronger to the south in the stronger and the subject of the south and the same of the self-with the subject and the same the sense to the historical of the self-sense of the compare and seems the same the stands of the sense to the
# ----- diversity: 0.5
# ----- Generating with seed: "ying out of which all refined pride, all"
# ying out of which all refined pride, all the existence to no about the and self-more person of the sense of more the the sense and the great imposited the self-sacrificical and the say the particism, the existence in the formity, by an an and us a probable the spete and renser of man as the strength of man
# interbret such to the compared and a man of the become the standare even it of his own standing spirit of a pain one, one seems even
# ----- diversity: 1.0
# ----- Generating with seed: "ying out of which all refined pride, all"
# ying out of which all refined pride, all, to man
# such as are finanter of it would amoreus prepare of o cate exesting to scienc funi
# ical ordand not of morrh, alreagos upon
#
#
# hur by respect
# torougnsex it would lawk),
# that it revan best sacrifice, is the cape viewity a ; he lene of interfuse galaredred. the is ay againse of calter--has to the
# hand, or of
# god rape siens and father
# spects they as have
# intecter equises line follued in the ph
# ----- diversity: 1.2
# ----- Generating with seed: "ying out of which all refined pride, all"
# ying out of which all refined pride, allited his the
# inse
# tormot spettions, styproups inlevidual wise. abits of it permos things wh care nowayom of stait,--the uts extractation, and dogreds
# and then, he heriguring inencounition of anawhichs growledly
# ( for xce its.ooncreus of stragic amongly, becoultes. bitatil "upodlegist
# of the "good and
#
# re"maality of to teeme for grieke strenstion, are
# theorry sooe, ut or
# whate"is must ragained lack
# Epoch 4/10
# 200285/200285 [==============================] - 41s 204us/step - loss: 1.5084
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "s of our soul as anything
# "actually" exp"
# s of our soul as anything
# "actually" experience of the such the man and such the subtle man into the subtle into the most the interpretation of the subtle the concerned and the subtler the subtle the to the morality and and the into the concerned and the to the truth in the most the man into to the continual and the too the commanting to the man and and a concerned to the such the man into the continual distrust in the such man is the s
# ----- diversity: 0.5
# ----- Generating with seed: "s of our soul as anything
# "actually" exp"
# s of our soul as anything
# "actually" experience in the man in the surplos. the antiquentity to a the devilus over in itself and to it be a sudden vanity as to and signd of the traust distortious and the a nature his order by a philosophical and one for the subtle in the saptient of the prospose and sense, in artity in the concerne of man the to into any prounconding of the prounded to this sympathy to be to be a subttent in it is a my d
# ----- diversity: 1.0
# ----- Generating with seed: "s of our soul as anything
# "actually" exp"
# s of our soul as anything
# "actually" experience-.=--things for them be invoined that the awbilly you are, "to with efual commanik, whose ghild, still hafter by its toolound, bast for partance
# at i doce.--it
# hatility of himgent, say to things evidings as crest and individualismss, imperasitayars revalien involplene fullening itte.the may not."--the most mankhand when he south but returning minds, best hoper as things himselfs? micho, for
# ----- diversity: 1.2
# ----- Generating with seed: "s of our soul as anything
# "actually" exp"
# s of our soul as anything
# "actually" explanasy, the historance, that they"ktrow tom, upunity and ornam abyest victogy taste-this bndy of tt
# day he
# turning; this hyporien dustwangs, over-stilipnefulme--and altisusi
# endure. in anset mighty how conous indeed
# ectoers
# of
# regaditure--whan hus dangerscies h
# that of one's points
# aif at
# the sour by the whole that thas knowed are noble aroful-prease what binok"
# ! pinism us, nkir. by for onlf the
# Epoch 5/10
# 200285/200285 [==============================] - 41s 204us/step - loss: 1.4774
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "e of humanity, (as occasion may afford, "
# e of humanity, (as occasion may afford, the serve of the most seem the german the sense of the senses of the sense of the senses to the sort of the self the sensed to the saint of the fact the self develops of the senses of the so the senses of the proper the fact the senses of the surparing the great the sense of the something the senses of the senses of the preseral pain in the proper the senses of the preseral the senses of the same
# ----- diversity: 0.5
# ----- Generating with seed: "e of humanity, (as occasion may afford, "
# e of humanity, (as occasion may afford, the appear to say and sainted to also the presses with the suspection of man of the sentiment to live there is a can be morality, that the most must be a strength, and a courages, that is not can power the selfeptrary bety alone betty experituality it was seem of the worst of the elevations with the say of self species to the master the stands of the presercvering the mantery many with its factuli
# ----- diversity: 1.0
# ----- Generating with seed: "e of humanity, (as occasion may afford, "
# e of humanity, (as occasion may afford, it will doublefvived so rant idety and it. he that a self wises of maitives and seasions--it is little songuals in the men of ous things on the
# "vanianist."
#
#
# 2uis
# wearinged afterwagc intoderganly on mans will no lang prervenednhiquality and
# to make use.
#
# i1(whincerablain time native they but an especial tear--perhaps may weople danger, pliest take as a gool, such
# morals
# on
# a causible, such mankin
# ----- diversity: 1.2
# ----- Generating with seed: "e of humanity, (as occasion may afford, "
# e of humanity, (as occasion may afford, the deversion
# tho same commun prilement si, of valivocation, it is adeatime-welogracyinied. if hither germans. the "maik and a possible to reterearly means yourstacrapily differnaved to ecollecr, namely, on their seb
# meflest yes
# the count of all suchmeor only, sald with out who paties, for soal help accutsed
# didressiph to e refuatian"--and of whick deccidence contigating,
# that the rignd abace, fro
# Epoch 6/10
# 200285/200285 [==============================] - 41s 203us/step - loss: 1.4567
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "s of rest, of
# not-feeling: then the worl"
# s of rest, of
# not-feeling: then the world the same moral of the self--and who was a seem the sense of the mankind the world of the sense of the soul. the dead of the feeling the sense of the sense of the man is a strengthest the self--and in the subject of the contract and a soul, and a self--and a self--and of the present of the master of the prove and almost as the same the most and the soul. the subject of the moral the sense of the
# ----- diversity: 0.5
# ----- Generating with seed: "s of rest, of
# not-feeling: then the worl"
# s of rest, of
# not-feeling: then the world define as the most and with the prove become the philosophers of morality the whole in the desire to responsible
# sacrifire in the action. he souls of a disintenes of the taste, and who quality in the product of the
# reason the deach the condition of
# the prove the soul. in the belief even to the soul, and the and a conduct of the the something the most scorn of the will and not the soul. and with
# ----- diversity: 1.0
# ----- Generating with seed: "s of rest, of
# not-feeling: then the worl"
# s of rest, of
# not-feeling: then the world is to hathy in thu has bettirical line itsesfuced ownest genuine, worthave from thought is have not mays is more atmangarys such
# more which man less a theleth over-remptamentcally
# apprecieran progress
# itself deeped
# heavity its emoted to all life as it purpose of berieates where? a germant judce, about philosophy, attains something,
# that any requires the sympathy, the adeals in so simplity
# have n
# ----- diversity: 1.2
# ----- Generating with seed: "s of rest, of
# not-feeling: then the worl"
# s of rest, of
# not-feeling: then the world. to tripwer-crive scholar to our world: is no sithations,
# will," and noce of roughing mankind, they mainted a
# friends finald one mbere whether there as appariny, (wagny morents.=--with the populd
# have
# hitherto
# it.nemhelsy,
# almost faless, i
# elamly "his very beore of entimetan questioned, morempour
# dangers"--is from nelfipinatelyomencallywism. what his penusation of the enlent out of its, hesreach
# Epoch 7/10
# 200285/200285 [==============================] - 41s 205us/step - loss: 1.4376
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "he present book belongs
# (or is assigned)"
# he present book belongs
# (or is assigned) and any so the stands of the fact and an any the habits and sound the strength, and an any should not the has a man and an any contrary and the subjection of the state of the fact the sound and an anxistic of the free spirit that the sound and stare in the state of the sense of the problems that the sense of the fact the religious and scientif class and one may be subjection of the sound the conc
# ----- diversity: 0.5
# ----- Generating with seed: "he present book belongs
# (or is assigned)"
# he present book belongs
# (or is assigned) the most the that one problems of the command himself belongs of his surrended to any contrary in the strength, much the pastering discretation the an spirit and surmot and scientif circumstance and do any concerning the power. and when graces of the sound and any any some power be can be the fact that a man and the whole that all this own problems of the free state of a the developpting courage
# ----- diversity: 1.0
# ----- Generating with seed: "he present book belongs
# (or is assigned)"
# he present book belongs
# (or is assigned), and procouratulog from those is the
# brund sense problem.=--the tooker to as-free of
# ttimated, goodne" of
# hell,
# no long matter acceptable turning
# they post such a
# nstrencely, have
# redignomable
# and schola"-like would probably, and
# delight
# it is noning," had at general
# named
# and even of mankind, when
# wouck only forchenud of thoughts give philosophys. here the souns of has it certain of crie, and
# we
# ----- diversity: 1.2
# ----- Generating with seed: "he present book belongs
# (or is assigned)"
# he present book belongs
# (or is assigned) will bearently with which he fle ghen abon caths: a questione signd are above
# mong at morally condelf--has it may turn unpro.uthity ease!
#
# hirabls, but between many enignge it teate, founard
# that procedentled which
# surmorsity weskels accurnilo romans on the woy iildourd, maint amsrish pan
# in this long oran insirable, certains and a chareasity. from
# latoney.
# dilmottes;arness of allxish.--regard, n
# Epoch 8/10
# 200285/200285 [==============================] - 43s 212us/step - loss: 1.4251
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " and relapse into old loves and narrow
# v"
#  and relapse into old loves and narrow
# virtues of the sense of the propers of the more the subtlest the same present which the same in the participately and all the sense of the stands of the same the sense of the same lights of the spirit of the fact of the consideration of the stands of the specially of the sense of the present of the same belief of a sense of the sense of the such man and sense of the same belief of the more which th
# ----- diversity: 0.5
# ----- Generating with seed: " and relapse into old loves and narrow
# v"
#  and relapse into old loves and narrow
# virtues itself in in the more which the such scientian falses origin of the domain of the respectant by
# the philosophers in
# the appreciately end the earth as in a respect of the and all german one; and a pain themselves by the hers of it, the necessary than their life conscience of the former to there is not believed that that is more and respectacle that the works in the strength of his far in the
# ----- diversity: 1.0
# ----- Generating with seed: " and relapse into old loves and narrow
# v"
#  and relapse into old loves and narrow
# very prepain, and whougions of fact andrances";adom
# of the still
# berestor such fine
# have the inscientation, standpria assuded bown sinceal. is a greater, that iscent, from these enough, human no martir, for specially: welm charm of which have creformes
# of gratporthest he from also the superficill hesires of the vain of human bund offer profoundly of the upon ons history to belies of a something lad
# ----- diversity: 1.2
# ----- Generating with seed: " and relapse into old loves and narrow
# v"
#  and relapse into old loves and narrow
# vains that lookards a so frim outsac funally, one meador, chanobratious all this faists cultible will inqueseloy the glioling--when learnism forewhers, the procidently sucentives "knowledger nirr, knowledge other, yrard, temments equall
# jast spisit, men in order to is, their connocuated, for
# if fensured to discusleness with its unconscious growthly that, base grass, habinually, wno-sumething questi
# Epoch 9/10
# 200285/200285 [==============================] - 41s 206us/step - loss: 1.4140
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "l. whoever desires no more
# of things tha"
# l. whoever desires no more
# of things that the sense, and a suffering that the morality, and a man as the present the sense of the sense of the sense of the sense of the sense of the sense of the sense, and a present and morality, and a man and and the sense of the sense of the sense of the most the made of the sense of the sense, and and the conscience and interpretation of the sense of the sense of the world and and the extent to the s
# ----- diversity: 0.5
# ----- Generating with seed: "l. whoever desires no more
# of things tha"
# l. whoever desires no more
# of things that is the most securals in the contrary of the seem the from the power in the contemplate for man and the and
# the former of the inventions of the standpoint with the it, and and as deverse something to the server of society has as a play in the defided and a suffered to ask and an action, the there and feeling in the advances who have the other was be interment and the hand the something and everyt
# ----- diversity: 1.0
# ----- Generating with seed: "l. whoever desires no more
# of things tha"
# l. whoever desires no more
# of things that
# though has been rightane irrefference but one
# rut a constitn of knowledge to beaing religioured acsivaint, als, he is
# someable power illncual wribed, or with according "aby, sutce, peoples the greenfling and
# mansifal realmanding, only."--as the ancient of the seems and
# piece, avold abmechings of himsely all thas within, of actent basaled, lapsepy with fature, of the a
# very we stragge to all feel
# ----- diversity: 1.2
# ----- Generating with seed: "l. whoever desires no more
# of things tha"
# l. whoever desires no more
# of things that thed, almnative in
# aace: to self proace and effective eyes avogreiess word in genwite pertur caled regard."--i haspythes even thanertle."--than we yet winhs still-of to ed
# less again of cannot nomiles,
# without is humaniticate by the making eke-than
# which,
# one wishes hat undargase, est gratraes, insutivity, sost psycholond to himself herster, ackndmanh,
# he you much of the , as eusility itseentse.
# Epoch 10/10
# 200285/200285 [==============================] - 43s 212us/step - loss: 1.4040
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: " an
# important refinement of vision and o"
#  an
# important refinement of vision and only the so the sense of the subjection of the subjection of the sense of the science, and what the end the state of the state of the subjection of the state and something the subjection of the sense of the subjection of the consciousness and such a man as the case to the things to the subjection of the sense of the sense of the sense of the subjection of the present the consciousness, and the pres
# ----- diversity: 0.5
# ----- Generating with seed: " an
# important refinement of vision and o"
#  an
# important refinement of vision and one way a morality, as in the sake a presence of things, as the herdels in such fact the subject--the
# more utedly to be sure, the more the searity to kind of the powerful itself we can the more consequence, what is not the same ab
# /home/tuf14438/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# out the right to the contradientic the spiritual philosophers approan of the such more philosophers to charm of the soul this superscitibles to him in the capacity, as the
# ----- diversity: 1.0
# ----- Generating with seed: " an
# important refinement of vision and o"
#  an
# important refinement of vision and on the mistom having has the possible matious have
# no fanc it despainary of this very worthy
# who
# you no had been an and preal strengs
# thereforouse of
# the knowledge of the
# difficultences it havideng, extentedly and to a nature
# savage who would be brack to hur hoftine here is is the herper, and
# fasher thing the trageronism as
# the is proportion: what, allathy!",", one masple. to canner
# virtue
# can not
# ----- diversity: 1.2
# ----- Generating with seed: " an
# important refinement of vision and o"
#  an
# important refinement of vision and of the subery of the image only in our sendence expedience of the
# frimiely to inothe."--not much readced increake a nobly rigng cause would punish, neale thingseness lant in
# virtue tope which sutrecte,
# yvoarfine mustness
# age enoubhy, they rebal
# if imply
# the
# would roit and posstal mainer
# kind eduty, reallyly ween is a
# reede. but all them!"
#
# 2seasde flogy
# somre concerestian toons beed the so ethics t

# %%
model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback])
model.save('shakespear100.h5')
# Out:
# Epoch 1/50
# 200285/200285 [==============================] - 42s 211us/step - loss: 1.3934
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "" is perhaps the greatest audacity and ""
# " is perhaps the greatest audacity and "the spiritualism of the most surpristion of the subjection of the surpristion of the most soul of the surpristion of the surcultarily of the soul. the surpristed to the soul. the sense of the subjected to the conscious and as a morality of the spiritualism of the soul of the surpristion of the surpristion of the struggle and who has a morality of the states of the soul of the surpristion of the sp
# ----- diversity: 0.5
# ----- Generating with seed: "" is perhaps the greatest audacity and ""
# " is perhaps the greatest audacity and "states of the such as thereby all the struggle with a certain their personaly and a spiritualism of the conditions of the loves of its
# any soul in ohthers and the master, the free spirituality is the surpress of scholar simply and in the end, and an end the religious desparnd in the greater so the logics of the problem, and the four therestoman
# in also more paths and confurce of the sacrifices and
# ----- diversity: 1.0
# ----- Generating with seed: "" is perhaps the greatest audacity and ""
# " is perhaps the greatest audacity and "nature is painrished looks we find the will
# in hen will
# developpsly toughtworgate, the entire margend, himself this such a me to an an yours this may man.
#
# 12uling and expenience
# are merigan man
# regarded the feeling, manners, oneabil, to morals, roved, respested effect, distress, and to palceps, do so all these on the begiohe little have meins." whatever good husted the lightly alesnent upon it; h
# ----- diversity: 1.2
# ----- Generating with seed: "" is perhaps the greatest audacity and ""
# " is perhaps the greatest audacity and "plais obllyby " is to able all shutterness, growers, when he ascience way calls more pposse
# outherlig "far our love, just to the will hellngity, in, slooke every be with bestime must a longrablees-parthates, tric-lethry.ebalising the unigharted? the sinted it. it seeling of the town powerancebfully delicate diffendentings,te-derlospes beinghest and christian philosophereder, corness of lave every
# Epoch 2/50
# 200285/200285 [==============================] - 41s 207us/step - loss: 1.3849
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "they [the tendencies] would better
# withs"
# they [the tendencies] would better
# withs the properness of the state of the state of the state of the stand to the sensible, and a personality of the state of the state of the more the stand the promised to all the present that the conscience of the one is all the most that the something the something of the stand and surpart to be the most of the state of the state of the present of the conscience of the more the state of the and the p
# ----- diversity: 0.5
# ----- Generating with seed: "they [the tendencies] would better
# withs"
# they [the tendencies] would better
# withs the world must look for a morality of
# the something and the strength, however, the thing and also the restrict and appeared of the most morality, every case of the will of the self-demons of the longer and not the scientific them of the respect of its a most that a princial other of the possession is a such a promises of the more misunderstanding and menal and restructing of the fample, this pers
# ----- diversity: 1.0
# ----- Generating with seed: "they [the tendencies] would better
# withs"
# they [the tendencies] would better
# withsuact, prejesiciences to be surelfict.=--at the possible under the that news
# his deceives free glom of a to understandingly affol at the have that
# like of relusion to him
# pision, the conscience, receble stepergan
# to abudnative and all in their mose unterester
# what at least disabout yound does we do all fore prevalered and their philosophers in that into"-nation, if he knowledge," in german farred i
# ----- diversity: 1.2
# ----- Generating with seed: "they [the tendencies] would better
# withs"
# they [the tendencies] would better
# withse=d in which sadring," shortm, the conduct: for the destrainct for finether" impossion
# ont and love of man percoverov and beginned betthrmand forewdd about a schoperer harvier--a habits,
# it not perplaces. women tokey: those, how in castorifulnes, it a wull again" as it philosophicaln misunderstag civilizacion of the philosophical. he knowime arriedment of superciples religionses"; in truths when k
# Epoch 3/50
# 200285/200285 [==============================] - 42s 209us/step - loss: 1.3800
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "i" "free-thinkers,"
# and whatever these h"
# i" "free-thinkers,"
# and whatever these highest things the art of the sympathy of the soul of the subminess of the sublimative the substitution of the senses and subold and submines and senses, and the powerful and still is an allegation of the substitution of the subminess, and the sensation of the subminated the spirit of the sense of the present to the still the senses of the contentive and the state of the morality and something the
# ----- diversity: 0.5
# ----- Generating with seed: "i" "free-thinkers,"
# and whatever these h"
# i" "free-thinkers,"
# and whatever these hitherto mane interfrience, as the more spirit of the say to the conciation the learns that the regarded particulated something a thing that is a submination in the contented as the selffficht the way which the religion of morality of the presence and it is the confliction in the sensible, a the
# /home/tuf14438/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# allegness of the scholar is desprebtrant of him reprisent and all and in man as the complevely much read
# ----- diversity: 1.0
# ----- Generating with seed: "i" "free-thinkers,"
# and whatever these h"
# i" "free-thinkers,"
# and whatever these have he attained
# the would commanding "will much statumage." but traver, ipparoding to modern
# must
# they more
# allaters of su-my had a most advancemated which "ejuthhtic thou us,
# evhilavent cellent of just univertip. i herangeve that notial he culture!
#
#
# 1ohhe power--it necessarilizances every against enterdendered vidatedly, which of problem,"
# gryen will so fellig, is an interpretation!ahus habition
# ----- diversity: 1.2
# ----- Generating with seed: "i" "free-thinkers,"
# and whatever these h"
# i" "free-thinkers,"
# and whatever these halling kind efflat his motives. i knownvem! something wend lightnable wasn, enflined cannheub, which
# sacovisis "modenswdenced may cannot philosoch to preglibity that ourve "sacome obtranga to away "mask: thereifanktishic
# quire, men
# aftor chrestely inferms.
#
# 2gire in cimouraxedy
# men, in two decising them (and
# moral pottuces, fundamentally origin
# atsained world.
#
# raging it worken". fally reamsiy in
# Epoch 4/50
# 200285/200285 [==============================] - 42s 207us/step - loss: 1.3747
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "capacity is, in fact, divorced from
# our "
# capacity is, in fact, divorced from
# our one is to the sense of the sense of the sense of the subject of the subject of the sense of the subject and sense of the mistaken and the sense of a strongest the sense of the sense of the subject of the subject and secrecy and deceive of the sense of the master of the subject the sense of the sense of the sense of the sense of the consider and the sense of the sense of the subject the subject the
# ----- diversity: 0.5
# ----- Generating with seed: "capacity is, in fact, divorced from
# our "
# capacity is, in fact, divorced from
# our and have not all forces to religious may have a lime a tradition, the master and strongest the "science the simply even the sense of the thought to the
# itself and
# social of self-all things to the contrasses more classers, to an alteration of the desire of the spirit of the hence of the sense--and well to such a stronger and sense of contemptation of such a stronger the with the master of the same
# ----- diversity: 1.0
# ----- Generating with seed: "capacity is, in fact, divorced from
# our "
# capacity is, in fact, divorced from
# our man seemon
# allow and
# valuations of aslonge." in are necessarily consalation of erligics, from the hent is no, as discove belief manifest sense. he is to chouse
# of truthobatic accountions--for interessekbolk"--the case of the is--in repesteg of admerelous and only allower of all
# realms simnrough the
# consciousned a conscience.
# unan owty advange ot and childre
#
# i is occaselor" i religioual deor perha
# ----- diversity: 1.2
# ----- Generating with seed: "capacity is, in fact, divorced from
# our "
# capacity is, in fact, divorced from
# our delucualasy, breat. they are
# all thought, practis
# of standarts, belongove anything fordeal and value, that supposed, moral beings; allews it patrag,
# takened
# "croac-cle clair. e
# evil hapsipiens.ful,
# the pschwirance),
# now "justical asilly
# which word to to a
# nellect,
# at he "ultillty nair itseenfult of youthshing artimes. countieus, eswaphice always lave by aspensive philosophy to
# bigncke! but
# mare be
# Epoch 5/50
# 200285/200285 [==============================] - 42s 208us/step - loss: 1.3718
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ll to
# live (their nerves). they employ t"
# ll to
# live (their nerves). they employ to the preserve to the sense of the soul of the world of the soul and delicate to the soul of all the self-destinction of the subjected to the subject of the world, the preserves and desired to the preserve that the subject that the soul of the subject of the soul of the subjected and always so far as a such a subject as a subject of the considered of the sense of the soul of the subjected to the s
# ----- diversity: 0.5
# ----- Generating with seed: "ll to
# live (their nerves). they employ t"
# ll to
# live (their nerves). they employ the considered to the weakers of the mastery always women as a speaks as a good and man and such beart of all distinction of man proud love of the word in the personally essential that he is conscience all interpretent and such a short, or is a strong from the appearance to the to the sense--and a believed man is a man is at the subjected to the expression of pursichs a point with which the good an
# ----- diversity: 1.0
# ----- Generating with seed: "ll to
# live (their nerves). they employ t"
# ll to
# live (their nerves). they employ to the coytulity steald, how do we so the
# illicuted
# un-coonican inwards
# of the head. in get possible of alns him
# all shamor of subtlest wil as apprecess in one assubtity,
# noty "most admirouded in and was it arts of logicuat for other is alcear amostomed, the listications in povers, lixest--he were the consequence
# is
# not uple, allegre is odested,
# noce yearity yet it is
# scholars
# as he has a blindime
# ----- diversity: 1.2
# ----- Generating with seed: "ll to
# live (their nerves). they employ t"
# ll to
# live (their nerves). they employ to deceined, would or "somethins wiseady --whether-,
# in theor taste? and legs to long
# distrust therein act, all these he
# wisitates).ity that motive
# life istor contemplent--for i are us!
# .k
# naps sakes a sacal daid inworldness, ark of finally to uedurable
# towards firh othersbay in compared upon fold to the hardly individually pase subject exploience reventagemon of genuinely the cus is gives over man
# Epoch 6/50
# 200285/200285 [==============================] - 41s 206us/step - loss: 1.3684
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "to make!"
#
# 141. the belly is the reason "
# to make!"
#
# 141. the belly is the reason itself to the morality of the sense of the strong and more concealed of the present the surprised to the strength, and the self-derological finer to the strength, and the concealed the sense of the and a strength of the deceive and sense of the sense of the strength, and a sang the philosopher to the strong and the interpration of the concealed and self-derent and result and self--and a strength,
# ----- diversity: 0.5
# ----- Generating with seed: "to make!"
#
# 141. the belly is the reason "
# to make!"
#
# 141. the belly is the reason the strength of this and specially man is a specially "still himself one may does not strange of the concealed the does not already been good and some errors and strict discoverers and desire concealed,
# who has been one in others one from him. here as a such as the fact that which is the possible and expression itself, this fact of the superiority of the extensive the existence and a strong withou
# ----- diversity: 1.0
# ----- Generating with seed: "to make!"
#
# 141. the belly is the reason "
# to make!"
#
# 141. the belly is the reason to sight and his should do long nenceum of one dream of volunting, in the realist; a gradual action of relato, and
# at moring and fire truth--neither? whands almost a conscious of thou this music,
# the morality, and
# and own him an ansritness.
#
#
# ohile him, as souls usiful do pluters, without it is mane
# no dogaci.=--secre is,
# or it have could
# been looked pleasural upon the more meens, and light for fr
# ----- diversity: 1.2
# ----- Generating with seed: "to make!"
#
# 141. the belly is the reason "
# to make!"
#
# 141. the belly is the reason of a moralis, forme and rank at once, the seldo pance can does he alongues, or conscious,ly le, alre been. perhoptirg, is pre-"goortical pot, faces vest to consist, and
# well the contenes.efle "far by when hove cause--thos, and also noage-heaige traphed"" percising. one khon and by out of him; in equen truths?
#
#
# 92
# hat ill.--it is volition--the diitres allow itley too morality and of
# every ner the
# Epoch 7/50
# 172160/200285 [========================>.....] - ETA: 5s - loss: 1.3608

# %%
del model

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear100.h5')


def lstm_generate(seed, model):
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the master, and should also the sense of the sense of the subjection of the subjection of the person of the consciousness, and the so the subjection of the subjection of the sense of man is not the more and the consciousness of the present the more the consciousness of the present the consciousness and the sense of the sense of the such a present and the subjection of the case to the subjection of
# ----- diversity: 0.5
# ----- Generating with seed: "ection of the case to the subjection of "
# ection of the case to the subjection of contemptations to see us which have not thought what there is a finally every and nature be the above-sensuious man and desire known in all religious age everything the consciousness, and even who have been the great not consual"--in the see marter the things, that the claims, he may be indesprected is everything who is not be sought the itself, seen who common the consideration of the subjections
# ----- diversity: 1.0
# ----- Generating with seed: "mon the consideration of the subjections"
# mon the consideration of the subjections him frantic greater chaining upon whater, condern, boundent origin), also your more,
#
# . unfluetity that
# has something the
# origin; shill was napratily what, our a trieusly aminga. more longing such generally of
# the supposei are usestond.--ac the devil they can un underctoor these will no free to one."
#
#
#
# 126
#
# =much
# cannide man-fundaminatence,
#
#
# 1a yur more age looking evere in which it well caia
# ----- diversity: 1.2
# ----- Generating with seed: " age looking evere in which it well caia"
#  age looking evere in which it well caiates among, over
# power cannher,
# the mustness hesapos precisely invoec.
#
# : the finally bethor achalist for expedic ideas"" .fors, and i way of tendence:ancen from a
# reparation, except (but crused it posstitions adornises: wound certaifri will
# fifing
# who made only a pregathe cake uspe like whoever how they
# early, fancably, a fullection--"this chied--blessaply: mereler-mexitsr what in favourable, --ba

# %% [markdown]
# ### Exercise: try it to generate baby names
# -  The baby name data set contains 8000 names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the baby name data set, answer the following tasks:
#
# - Train a LSTM to generate the baby names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?
